# %%
import json
from list_dict_DB import list_dict_DB
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-65-1eeddcec51b5> in <module>()
#       1 import json
# ----> 2 from list_dict_DB import list_dict_DB
#
# ModuleNotFoundError: No module named 'list_dict_DB'

# %%
file = open("ticket.json", "r")
if file.mode == 'r':
    contents = file.read()
    contents = contents.replace('\n','')
    contents = b.replace('\u200b', '')
    contents = eval(contents)

# %%
contents
# Out:
# [{'Airlines': 'Singapore Airlines',
#   'Connection': 'False',
#   'Date': '22/08/2019',
#   'Flight No': 'SA1234',
#   'From': 'Chennai',
#   'Price': 'Rs 22,000',
#   'Ref_no': '1290,432,454545,667567,32312',
#   'Seats': 25,
#   'To': 'Singapore'},
#  {'Airlines': 'China Airlines',
#   'Connection': 'False',
#   'Date': '22/08/2019',
#   'Flight No': 'CA1434',
#   'From': 'Chennai',
#   'Price': 'Rs 19,000',
#   'Ref_no': '129032,43247,84432,235674,976543',
#   'Seats': 25,
#   'To': 'Singapore'},
#  {'Airlines': 'ABC Airlines',
#   'Connection': 'True',
#   'Date': '22/08/2019',
#   'Flight No': 'AA234',
#   'From': 'Chennai',
#   'Price': 'Rs 13,000',
#   'Ref_no': '129023,45643,23423412,65757',
#   'Seats': 25,
#   'To': 'Singapore'},
#  {'Airlines': 'XYZ Airlines',
#   'Connection': 'True',
#   'Date': '22/08/2019',
#   'Flight No': 'YZ1234',
#   'From': 'Chennai',
#   'Price': 'Rs 12,000',
#   'Ref_no': '1290231,53523,4324656,78867,2426475,78675',
#   'Seats': 25,
# ...

# %%
[content for content in contents if content['Airlines']=='Singapore Airlines' and contents['Date']=='22/08/2019']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-64-cd86bfe7c53e> in <module>()
# ----> 1 [content for content in contents if content['Airlines']=='Singapore Airlines' and contents['Date']=='22/08/2019']
#
# <ipython-input-64-cd86bfe7c53e> in <listcomp>(.0)
# ----> 1 [content for content in contents if content['Airlines']=='Singapore Airlines' and contents['Date']=='22/08/2019']
#
# TypeError: list indices must be integers or slices, not str
